# %%
from pyforest import *

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "suvidyasonawane/spam-vs-ham-emails",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_13704\4241060797.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       7 file_path = ""
#       9 # Load the latest version
# ---> 10 df = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.PANDAS,
#      12   "suvidyasonawane/spam-vs-ham-emails",
#      13   file_path,
#      14   # Provide any additional arguments like
#      15   # sql_query or pandas_kwargs. See the
#      16   # documenation for more information:
#      17   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
#      18 )
#      20 print("First 5 records:", df.head())
#
# File D:\anaconda\Lib\site-packages\kagglehub\datasets.py:178, in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     163 def load_dataset(
#     164     adapter: KaggleDatasetAdapter,
#     165     # In the form of {owner_slug}/{dataset_slug} or {owner_slug}/{dataset_slug}/versions/{version_number}
#    (...)
#     171     hf_kwargs: Any = None,  # noqa: ANN401
#     172 ) -> Any:  # noqa: ANN401
#     173     warnings.warn(
#     174         "Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.",
#     175         DeprecationWarning,
#     176         stacklevel=2,
#     177     )
# --> 178     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
#
# File D:\anaconda\Lib\site-packages\kagglehub\datasets.py:141, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs, polars_frame_type, polars_kwargs)
#     138 elif adapter is KaggleDatasetAdapter.PANDAS:
#     139     import kagglehub.pandas_datasets  # noqa: PLC0415
# --> 141     return kagglehub.pandas_datasets.load_pandas_dataset(
#     142         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     143     )
#     144 elif adapter is KaggleDatasetAdapter.POLARS:
#     145     import kagglehub.polars_datasets  # noqa: PLC0415
#
# File D:\anaconda\Lib\site-packages\kagglehub\pandas_datasets.py:86, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      84 pandas_kwargs = {} if pandas_kwargs is None else pandas_kwargs
#      85 file_extension = os.path.splitext(path)[1]
# ---> 86 read_function = _validate_read_function(file_extension, sql_query)
#      88 # Now that everything has been validated, we can start downloading and processing
#      89 filepath = dataset_download(handle, path)
#
# File D:\anaconda\Lib\site-packages\kagglehub\pandas_datasets.py:108, in _validate_read_function(file_extension, sql_query)
#     103 if file_extension not in SUPPORTED_READ_FUNCTIONS_BY_EXTENSION:
#     104     extension_error_message = (
#     105         f"Unsupported file extension: '{file_extension}'. "
#     106         f"Supported file extensions are: {', '.join(SUPPORTED_READ_FUNCTIONS_BY_EXTENSION.keys())}"
#     107     )
# --> 108     raise ValueError(extension_error_message) from None
#     110 read_function = SUPPORTED_READ_FUNCTIONS_BY_EXTENSION[file_extension]
#     111 if read_function is wrapped_read_sql_query and not sql_query:
#
# ValueError: Unsupported file extension: ''. Supported file extensions are: .csv, .tsv, .json, .jsonl, .xml, .parquet, .feather, .sqlite, .sqlite3, .db, .db3, .s3db, .dl3, .xls, .xlsx, .xlsm, .xlsb, .odf, .ods, .odt

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

file_path = "spam_ham_dataset.csv"

df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "suvidyasonawane/spam-vs-ham-emails",
    file_path
)

print("First 5 records:")
print(df.head())
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_13704\3511048874.py:6: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File D:\anaconda\Lib\site-packages\kagglehub\exceptions.py:66, in kaggle_api_raise_for_status(response, resource_handle)
#      65 try:
# ---> 66     response.raise_for_status()
#      67 except requests.HTTPError as e:
#
# File D:\anaconda\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.kaggle.com/api/v1/datasets/download/suvidyasonawane/spam-vs-ham-emails?dataset_version_number=1&file_name=spam_ham_dataset.csv
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[6], line 6
#       2 from kagglehub import KaggleDatasetAdapter
#       4 file_path = "spam_ham_dataset.csv"
# ----> 6 df = kagglehub.load_dataset(
#       7     KaggleDatasetAdapter.PANDAS,
#       8     "suvidyasonawane/spam-vs-ham-emails",
#       9     file_path
#      10 )
#      12 print("First 5 records:")
#      13 print(df.head())
#
# File D:\anaconda\Lib\site-packages\kagglehub\datasets.py:178, in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     163 def load_dataset(
#     164     adapter: KaggleDatasetAdapter,
#     165     # In the form of {owner_slug}/{dataset_slug} or {owner_slug}/{dataset_slug}/versions/{version_number}
#    (...)
#     171     hf_kwargs: Any = None,  # noqa: ANN401
#     172 ) -> Any:  # noqa: ANN401
#     173     warnings.warn(
#     174         "Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.",
#     175         DeprecationWarning,
#     176         stacklevel=2,
#     177     )
# --> 178     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
#
# File D:\anaconda\Lib\site-packages\kagglehub\datasets.py:141, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs, polars_frame_type, polars_kwargs)
#     138 elif adapter is KaggleDatasetAdapter.PANDAS:
#     139     import kagglehub.pandas_datasets  # noqa: PLC0415
# --> 141     return kagglehub.pandas_datasets.load_pandas_dataset(
#     142         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     143     )
#     144 elif adapter is KaggleDatasetAdapter.POLARS:
#     145     import kagglehub.polars_datasets  # noqa: PLC0415
#
# File D:\anaconda\Lib\site-packages\kagglehub\pandas_datasets.py:89, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      86 read_function = _validate_read_function(file_extension, sql_query)
#      88 # Now that everything has been validated, we can start downloading and processing
# ---> 89 filepath = dataset_download(handle, path)
#      90 try:
#      91     result = read_function(
#      92         *_build_args(read_function, filepath, sql_query),
#      93         **_build_kwargs(file_extension, pandas_kwargs),
#      94     )
#
# File D:\anaconda\Lib\site-packages\kagglehub\datasets.py:43, in dataset_download(handle, path, force_download)
#      41 h = parse_dataset_handle(handle)
#      42 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44 return path
#
# File D:\anaconda\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File D:\anaconda\Lib\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)
#      27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File D:\anaconda\Lib\site-packages\kagglehub\http_resolver.py:122, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     119 if path:
#     120     # Downloading a single file.
#     121     os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 122     api_client.download_file(url_path, out_path, h, extract_auto_compressed_file=True)
#     123 else:
#     124     # TODO(b/345800027) Implement parallel download when < 25 files in databundle.
#     125     # Downloading the full archived bundle.
#     126     archive_path = get_cached_archive_path(h)
#
# File D:\anaconda\Lib\site-packages\kagglehub\clients.py:182, in KaggleApiV1Client.download_file(self, path, out_file, resource_handle, cached_path, extract_auto_compressed_file)
#     174 url = self._build_url(path)
#     175 with requests.get(
#     176     url,
#     177     headers={"User-Agent": get_user_agent()},
#    (...)
#     180     timeout=(DEFAULT_CONNECT_TIMEOUT, DEFAULT_READ_TIMEOUT),
#     181 ) as response:
# --> 182     kaggle_api_raise_for_status(response, resource_handle)
#     184     total_size = int(response.headers["Content-Length"]) if "Content-Length" in response.headers else None
#     185     size_read = 0
#
# File D:\anaconda\Lib\site-packages\kagglehub\exceptions.py:106, in kaggle_api_raise_for_status(response, resource_handle)
#      97     message = (
#      98         f"{response.status_code} Client Error."
#      99         "\n\n"
#    (...)
#     102         "Please make sure you specified the correct resource identifiers."
#     103     )
#     105 # Default handling
# --> 106 raise KaggleApiHTTPError(message, response=response) from e
#
# KaggleApiHTTPError: 404 Client Error.
#
# Resource not found at URL: https://www.kaggle.com/datasets/suvidyasonawane/spam-vs-ham-emails/versions/1
# The server reported the following issues: Data not found
# Please make sure you specified the correct resource identifiers.
