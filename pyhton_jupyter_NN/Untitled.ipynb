# %%
# hello my name is ankit

# %% [markdown]
# ## Hello Workld

# %%
10*ankit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 10*ankit
#
# NameError: name 'ankit' is not defined

# %%
10**2
# Out:
# 100

# %%
marks=10

# %%
a=100
b=50
print(a-b)
# Out:
# 50

# %%
len("ankit")
type("ankit")
# Out:
# str

# %%
name="Ankitpatel"

# %%
print(name.isalnum())
print(name.istitle()) # check for the first letter is capital or not if capital then return true and not the return false
name.isdigit()
# Out:
# True
# True
# False

# %%
name = ["ankit" , "rashi"]
print(name[0] + " " + name[1])
# Out:
# ankit rashi

# %%
name.append("nomorenames")

# %% [raw]
# print(name)
