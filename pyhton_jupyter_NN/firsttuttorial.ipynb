# %%
#fljd;lk

# %%
set_val = {1,2,3,4,5,2,3}

# %%
set_val
# Out:
# {1, 2, 3}

# %%
# exploring about dict

# %%
car_names = {"car1": "mercedes benz" , "car2" : "lamborgini"}
car_names['car2']
# Out:
# 'lamborgini'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 car_names['car1']
#
# NameError: name 'car_names' is not defined
