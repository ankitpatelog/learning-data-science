# %%
#lambda function in python
add = lambda a,b:a+b
add(2,3)
# Out:
# 5

# %%
is_even = lambda a : if a%2==0
return true

# %%
def make_upper(name):
    return name.upper()

name = ['ankit', 'rashi','shubham']
result = list(map(make_upper,name))
result
# Out:
# ['ANKIT', 'RASHI', 'SHUBHAM']
